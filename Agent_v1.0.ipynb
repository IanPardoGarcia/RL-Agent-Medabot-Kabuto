# %% [markdown]
# # Environment

# %%
import numpy as np
import os
from pyboy import PyBoy
from gymnasium import Env, spaces
from stable_baselines3 import PPO
from stable_baselines3.ppo import MultiInputPolicy
from stable_baselines3.common.env_checker import check_env
from gymnasium.wrappers import TransformObservation
from gymnasium.spaces import Box, Dict

# List of actions
ACTIONS = ['a', 'b', 'left', 'right', 'up', 'down']

# Definir posiciones objetivo con orientación (x, y, map, orientation)
TARGET_POSITIONS = [
    (16, 8, 80, 1),  # Target Position 1
    (17, 9, 80, 2),  # Target Position 2
    (16, 10, 80, 0)   # Target Position 3
]
class GenericPyBoyEnv(Env):
    def __init__(self, pyboy, debug=False, render_mode=False, max_gameplay_time=1080000):
        super().__init__()
        self.pyboy = pyboy
        self.debug = debug
        self.render_mode = render_mode
        self.max_gameplay_time = max_gameplay_time
        self.current_gameplay_time = 0
        
        self.action_space = spaces.Discrete(len(ACTIONS))
        self.observation_space = Dict({
           "info": Box(0, 255, (4,), dtype=np.float32)  # Added orientation
        })
        
        self.visited_maps = set()
        self.visited_positions = set()
        self.last_pos = None
        
        if not self.debug:
            self.pyboy.set_emulation_speed(9 if not self.render_mode else 3)
        
        self.load_state()

    def load_state(self):
        with open("zero_state.state", "rb") as f:
            self.pyboy.load_state(f)

    def get_observation(self):
        pos_x = self.pyboy.memory[0xC0D4]
        pos_y = self.pyboy.memory[0xC0D5]
        map_id = self.pyboy.memory[0xC92D]
        orientation = self.pyboy.memory[0xC0D8]

        return {
            "info": np.array([pos_x, pos_y, map_id, orientation], dtype=np.float32)
        }

    def step(self, action):
        self.pyboy.button(ACTIONS[action])
        for _ in range(60):
            self.pyboy.tick()
            self.current_gameplay_time += 1
            
        timeout = self.current_gameplay_time >= self.max_gameplay_time
        
        pos_x = self.pyboy.memory[0xC0D4]
        pos_y = self.pyboy.memory[0xC0D5]
        map_value = self.pyboy.memory[0xC92D]
        orientation = self.pyboy.memory[0xC0D8]
        full_position = (pos_x, pos_y, map_value, orientation)
        # Check if the agent reached *any* of the target positions and pressed 'A'
        reached_target = full_position in TARGET_POSITIONS and action == 0
        #reached_target = self.pyboy.memory[0xC92D] == 107
        reward = -0.001

        #if full_position not in self.visited_positions:
         #   reward += 1
            #print("New position")

        #if full_position == self.last_pos and action in [2, 3, 4, 5]:
         #   reward -= 0.05
            #print("Invalid move")
        if map_value not in self.visited_maps:
            print("New Map")
            reward += 1
            
        if reached_target:
            print("You Win!")
            reward += 10  # Large reward for reaching the goal and pressing 'A'

        # If timeout happens, give a small penalty
        if timeout:
            #reward -= 10
            print("GAME OVER")

        self.visited_maps.add(map_value)
        self.visited_positions.add(full_position)
        self.last_pos = full_position

        # Done condition: timeout or reaching target position & pressing 'A'
        done = timeout or reached_target

        return self.get_observation(), reward, done, False, {}

    def reset(self, seed=None, **kwargs):
        self.load_state()
        self.current_gameplay_time = 0
        self.visited_positions.clear()
        self.visited_maps.clear()
        return self.get_observation(), {}

    def close(self):
        self.pyboy.stop()
# Out:
# UserWarning: Using SDL2 binaries from pysdl2-dll 2.30.10

# %% [markdown]
# # Training Agent 1 ENV

# %%
from pyboy import PyBoy
from stable_baselines3 import PPO
from stable_baselines3.ppo import MultiInputPolicy
from gymnasium.wrappers import TransformObservation
from gymnasium.spaces import Dict
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
import matplotlib.pyplot as plt
import pandas as pd

# Load PyBoy and initialize environment
pyboy = PyBoy(r"C:\Users\USUARIO\Desktop\RLMEDA\MedarotKabuto.gb")
train_env = GenericPyBoyEnv(pyboy, debug=False, render_mode=True)

# Transform observation to remove unnecessary screen info
train_env = TransformObservation(
    train_env,
    lambda obs: {"info": obs["info"]},  # Solo usar la información de posición
    observation_space=Dict({"info": Box(0, 255, (4,), dtype=np.float32)})  # Ajuste de límites
)

# Validate environment
#check_env(train_env, warn=True)

# Train PPO model with optimized hyperparameters comment if u want to see training
train_env = Monitor(train_env, filename="./ppo_medarot_logs")

model = PPO(
    MultiInputPolicy,
    train_env,
    verbose=1,
    learning_rate=1e-4,  # Slower learning for better convergence
    n_steps=4096,  # More steps before updates
    gamma=0.995,  # Encourage long-term planning
    ent_coef=0.1,  # More exploration during training
    batch_size=512,  # Larger batch for stability
    clip_range=0.2,  # Less restrictive clipping
    tensorboard_log="./ppo_tensorboard/"
)
# Train for more timesteps for better learning
model.learn(total_timesteps=100000)  
model.save("ppo_medarot")
# Out:
# New Map
# New Map
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Logging to ./ppo_tensorboard/PPO_27
# New Map

# %% [markdown]
# # Evaluate for 5 episodes

# %%
# Evaluación del modelo
model = PPO.load("ppo_medarot")
pyboy = PyBoy(r"C:\Users\USUARIO\Desktop\RLMEDA\MedarotKabuto.gb")
eval_env = GenericPyBoyEnv(pyboy, debug=False, render_mode=False)
eval_env = TransformObservation(
    eval_env,
    lambda obs: {"info": obs["info"]},
    observation_space=eval_env.observation_space
)


# Evaluar el modelo entrenado
num_episodes = 5
total_rewards = []

for episode in range(num_episodes):
    obs, _ = eval_env.reset()
    total_reward = 0

    for _ in range(3600):  # 10 minutos, 1 acción por segundo
        # Asegurar que la observación es un diccionario (como en `observation_space`)
        if not isinstance(obs, dict):
            raise ValueError(f"La observación esperada es un diccionario, pero se recibió: {type(obs)}")

        # Obtener la acción del modelo
        action, _ = model.predict(obs)  # No concatenar, usar directamente el diccionario

        # Tomar un paso en el entorno
        obs, reward, done, truncated, _ = eval_env.step(action)
        total_reward += reward

        if done:
            break

    total_rewards.append(total_reward)
    print(f"Episodio {episode + 1}: Recompensa total: {total_reward}")

# Imprimir la recompensa promedio
print(f"Recompensa promedio en {num_episodes} episodios: {np.mean(total_rewards)}")
# Out:
# You Win!
# Episodio 1: Recompensa total: 1
# You Win!
# Episodio 2: Recompensa total: 1
# You Win!
# Episodio 3: Recompensa total: 1
# You Win!
# Episodio 4: Recompensa total: 1
# You Win!
# Episodio 5: Recompensa total: 1
# Recompensa promedio en 5 episodios: 1.0

# %% [markdown]
# # Train Agent in 4 Env

# %%
from pyboy import PyBoy
from stable_baselines3 import PPO
from stable_baselines3.ppo import MultiInputPolicy
from gymnasium.wrappers import TransformObservation
from gymnasium.spaces import Box, Dict
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import SubprocVecEnv
import numpy as np
import matplotlib.pyplot as plt

# Define a function to create environments for SubprocVecEnv
def make_env():
    pyboy = PyBoy(r"C:\Users\USUARIO\Desktop\RLMEDA\MedarotKabuto.gb")
    train_env = GenericPyBoyEnv(pyboy, debug=False, render_mode=False)

    # Transform observation to remove unnecessary screen info
    train_env = TransformObservation(
        train_env,
        lambda obs: {"info": obs["info"]},  # Only use position info
        observation_space=Dict({
            "info": Box(low=0, high=255, shape=(4,), dtype=np.float32)  # Adjusted shape and dtype
        })
    )
# Validate environment
    #check_env(train_env, warn=True)

# Monitor to log training information
    return Monitor(train_env, filename="./ppo_medarot_logs")

# Number of parallel environments
num_envs = 8  # Use 4 parallel environments
vec_env = SubprocVecEnv([make_env for _ in range(num_envs)])

# Configuring PPO with the vectorized environment
model = PPO(
    MultiInputPolicy,
    vec_env,
    verbose=1,
    learning_rate=1e-4,
    n_steps=4096,  # Ensure divisible by num_envs for batch updates
    batch_size=512,
    gamma=0.999,
    gae_lambda=0.95,
    ent_coef=0.1,
    clip_range=0.2,
    tensorboard_log="./ppo_tensorboard/"
)

# Train the model for 50,000 timesteps
model.learn(total_timesteps=900000)
model.save("ppo_medarot_2")
# Out:
# Using cpu device
# Logging to ./ppo_tensorboard/PPO_29
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.01e+03 |
# |    ep_rew_mean     | 12       |
# | time/              |          |
# |    fps             | 101      |
# |    iterations      | 1        |
# |    time_elapsed    | 323      |
# |    total_timesteps | 32768    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.81e+03     |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 2            |
# |    time_elapsed         | 619          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0030895197 |
# |    clip_fraction        | 0.000287     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | 0.00922      |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.152       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000612    |
# |    value_loss           | 0.069        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.49e+03     |
# |    ep_rew_mean          | 10.5         |
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 3            |
# |    time_elapsed         | 914          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0041102553 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | 0.0883       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.084        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 0.302        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.29e+03    |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 4           |
# |    time_elapsed         | 1201        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004499398 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0895     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00319    |
# |    value_loss           | 0.293       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.34e+03     |
# |    ep_rew_mean          | 10.7         |
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 5            |
# |    time_elapsed         | 1492         |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0042491346 |
# |    clip_fraction        | 0.00275      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.354        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.133       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 0.203        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.93e+03     |
# |    ep_rew_mean          | 11.1         |
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 6            |
# |    time_elapsed         | 1777         |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0047415816 |
# |    clip_fraction        | 9.46e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.523        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.112       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000969    |
# |    value_loss           | 0.164        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.49e+03    |
# |    ep_rew_mean          | 11.5        |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 7           |
# |    time_elapsed         | 2079        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.006137289 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0113      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 0.468       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.27e+03     |
# |    ep_rew_mean          | 11.7         |
# | time/                   |              |
# |    fps                  | 110          |
# |    iterations           | 8            |
# |    time_elapsed         | 2374         |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0063163866 |
# |    clip_fraction        | 0.00145      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.694        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.172        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 0.458        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 9           |
# |    time_elapsed         | 2717        |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.004737499 |
# |    clip_fraction        | 0.00545     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0308     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00158    |
# |    value_loss           | 0.373       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.42e+03    |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 10          |
# |    time_elapsed         | 3059        |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.004896569 |
# |    clip_fraction        | 0.00577     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0284      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 0.435       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.37e+03     |
# |    ep_rew_mean          | 12.6         |
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 11           |
# |    time_elapsed         | 3385         |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0022898875 |
# |    clip_fraction        | 0.00267      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0411       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 0.421        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.37e+03    |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 105         |
# |    iterations           | 12          |
# |    time_elapsed         | 3720        |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.006071677 |
# |    clip_fraction        | 0.00583     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0376      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 0.388       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.33e+03   |
# |    ep_rew_mean          | 12.7       |
# | time/                   |            |
# |    fps                  | 104        |
# |    iterations           | 13         |
# |    time_elapsed         | 4057       |
# |    total_timesteps      | 425984     |
# | train/                  |            |
# |    approx_kl            | 0.01095556 |
# |    clip_fraction        | 0.0352     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.76      |
# |    explained_variance   | 0.876      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0878    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.000806  |
# |    value_loss           | 0.226      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 12.8        |
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 14          |
# |    time_elapsed         | 4395        |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.007022851 |
# |    clip_fraction        | 0.0233      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0372      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 0.451       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 963          |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 15           |
# |    time_elapsed         | 4734         |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0034003875 |
# |    clip_fraction        | 0.000656     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.905        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0171      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 0.328        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 946         |
# |    ep_rew_mean          | 13.1        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 16          |
# |    time_elapsed         | 5069        |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.003370011 |
# |    clip_fraction        | 0.00582     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0121      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000698   |
# |    value_loss           | 0.441       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 828         |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 17          |
# |    time_elapsed         | 5378        |
# |    total_timesteps      | 557056      |
# | train/                  |             |
# |    approx_kl            | 0.008010231 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0154      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 0.382       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 737          |
# |    ep_rew_mean          | 13.3         |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 18           |
# |    time_elapsed         | 5706         |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0076098414 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.102        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 0.579        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 676         |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 19          |
# |    time_elapsed         | 6035        |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.005393632 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0185      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 0.434       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 505         |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 20          |
# |    time_elapsed         | 6346        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.004940547 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.125       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 0.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 21          |
# |    time_elapsed         | 6651        |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.004807493 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.16        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 0.636       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 470         |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 22          |
# |    time_elapsed         | 6964        |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.005390499 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.1         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 0.544       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 512          |
# |    ep_rew_mean          | 13.5         |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 23           |
# |    time_elapsed         | 7292         |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0067755356 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0904       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 0.543        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 552          |
# |    ep_rew_mean          | 13.4         |
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 24           |
# |    time_elapsed         | 7624         |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0076198187 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0872       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 0.451        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 555         |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 25          |
# |    time_elapsed         | 7933        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.005605927 |
# |    clip_fraction        | 0.0304      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0314      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 0.413       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 666         |
# |    ep_rew_mean          | 13.3        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 26          |
# |    time_elapsed         | 8232        |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.006108192 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0055     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 0.402       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 799         |
# |    ep_rew_mean          | 13.2        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 27          |
# |    time_elapsed         | 8533        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.008157421 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0269     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 0.288       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 867         |
# |    ep_rew_mean          | 13.1        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 28          |
# |    time_elapsed         | 8869        |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.008213086 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.133      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 0.135       |
# -----------------------------------------

# %% [markdown]
# # Plot Best Policy

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Evaluate the policy on a fresh environment and visualize the trajectory
def test_policy(model):
    # Initialize a test environment
    test_env = make_env()
    obs, info = test_env.reset()

    done = False
    test_positions = []

    # Test the learned policy
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = test_env.step(action)  # Unpack 5 values
        print(obs)
        test_positions.append((obs["info"][0], obs["info"][1]))  # Record positions
        
    # Plot the trajectory
    test_positions = np.array(test_positions)
    #print(test_positions)
    final_position = len(test_positions) - 1
    plt.plot(test_positions[:, 0], test_positions[:, 1], marker="o", linestyle="-")
    plt.plot(test_positions[0, 0], test_positions[0, 1], "g^")  # Starting point
    plt.plot(test_positions[final_position, 0], test_positions[final_position, 1], "rs")  # Final point
    plt.xlabel("Posición X")
    plt.ylabel("Posición Y")
    plt.title("Trayectoria del agente en la prueba")
    plt.show()

# Load the trained PPO model
model = PPO.load("ppo_medarot")  # Load your trained model

# Test the policy on a single environment and visualize the trajectory
test_policy(model)
# Out:
# New Map
# New Map
# New Map
# {'info': array([  4.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  3.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  3.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# New Map
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  2.,   5., 107.,   3.], dtype=float32)}
# {'info': array([  2.,   5., 107.,   0.], dtype=float32)}
# {'info': array([  2.,   5., 107.,   0.], dtype=float32)}
# {'info': array([  2.,   6., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   6., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   4., 124.,   3.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  2.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# ...
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  2.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   5., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  2.,   3., 124.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   3.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   4., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 124.,   1.], dtype=float32)}
# {'info': array([  1.,   2., 124.,   0.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   1.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   3., 107.,   2.], dtype=float32)}
# {'info': array([  1.,   2., 107.,   0.], dtype=float32)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 35
#      32 model = PPO.load("ppo_medarot")  # Load your trained model
#      34 # Test the policy on a single environment and visualize the trajectory
# ---> 35 test_policy(model)
#
# Cell In[3], line 15, in test_policy(model)
#      13 while not done:
#      14     action, _ = model.predict(obs)
# ---> 15     obs, reward, done, truncated, info = test_env.step(action)  # Unpack 5 values
#      16     print(obs)
#      17     test_positions.append((obs["info"][0], obs["info"][1]))  # Record positions
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~\anaconda3\Lib\site-packages\gymnasium\core.py:550, in ObservationWrapper.step(self, action)
#     546 def step(
#     547     self, action: ActType
#     548 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     549     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 550     observation, reward, terminated, truncated, info = self.env.step(action)
#     551     return self.observation(observation), reward, terminated, truncated, info
#
# Cell In[1], line 60, in GenericPyBoyEnv.step(self, action)
#      58 self.pyboy.button(ACTIONS[action])
#      59 for _ in range(60):
# ---> 60     self.pyboy.tick()
#      61     self.current_gameplay_time += 1
#      63 timeout = self.current_gameplay_time >= self.max_gameplay_time
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Evaluate the policy on a fresh environment and visualize the trajectory
def test_policy(model):
    # Initialize a test environment
    test_env = make_env()
    obs, info = test_env.reset()

    done = False
    map_positions = {}  # Dictionary to store positions per map

    # Test the learned policy
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, truncated, info = test_env.step(action)  # Unpack 5 values
        
        map_id = int(obs["info"][2])  # Third value in "info" array
        position = (obs["info"][0], obs["info"][1])  # X, Y coordinates

        # Store position in the corresponding map
        if map_id not in map_positions:
            map_positions[map_id] = []
        map_positions[map_id].append(position)

    # Create a separate plot for each map
    for map_id, positions in map_positions.items():
        positions = np.array(positions)

        plt.figure(figsize=(6, 6))
        plt.plot(positions[:, 0], positions[:, 1], marker="o", linestyle="-", color="b", label=f"Map {map_id}")
        plt.plot(positions[0, 0], positions[0, 1], "g^", markersize=10, label="Start")  # Starting point
        plt.plot(positions[-1, 0], positions[-1, 1], "rs", markersize=10, label="End")  # Final point

        plt.xlabel("Posición X")
        plt.ylabel("Posición Y")
        plt.title(f"Trayectoria en el Mapa {map_id}")
        plt.legend()
        plt.grid()
        plt.show()

# Load the trained PPO model
model = PPO.load("ppo_medarot")  # Load your trained model

# Test the policy on a single environment and visualize the trajectory
test_policy(model)
# Out:
# New Map
# New Map
# New Map
# New Map
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 46
#      43 model = PPO.load("ppo_medarot")  # Load your trained model
#      45 # Test the policy on a single environment and visualize the trajectory
# ---> 46 test_policy(model)
#
# Cell In[7], line 16, in test_policy(model)
#      14 while not done:
#      15     action, _ = model.predict(obs)
# ---> 16     obs, reward, done, truncated, info = test_env.step(action)  # Unpack 5 values
#      18     map_id = int(obs["info"][2])  # Third value in "info" array
#      19     position = (obs["info"][0], obs["info"][1])  # X, Y coordinates
#
# File ~\anaconda3\Lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~\anaconda3\Lib\site-packages\gymnasium\core.py:550, in ObservationWrapper.step(self, action)
#     546 def step(
#     547     self, action: ActType
#     548 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     549     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 550     observation, reward, terminated, truncated, info = self.env.step(action)
#     551     return self.observation(observation), reward, terminated, truncated, info
#
# Cell In[1], line 60, in GenericPyBoyEnv.step(self, action)
#      58 self.pyboy.button(ACTIONS[action])
#      59 for _ in range(60):
# ---> 60     self.pyboy.tick()
#      61     self.current_gameplay_time += 1
#      63 timeout = self.current_gameplay_time >= self.max_gameplay_time
#
# KeyboardInterrupt:

# %% [markdown]
# # Continue Training a Model Not working

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv
from gymnasium.wrappers import TransformObservation
from gymnasium.spaces import Box, Dict
import numpy as np

# Reload the previously saved PPO model
model = PPO.load("ppo_medarot")

# Define a function to recreate the environment (if it was customized)
def make_env():
    pyboy = PyBoy(r"C:\Users\USUARIO\Desktop\RLMEDA\MedarotKabuto.gb")
    train_env = GenericPyBoyEnv(pyboy, debug=False, render_mode=False)

    # Transform observation to remove unnecessary screen info
    train_env = TransformObservation(
        train_env,
        lambda obs: {"info": obs["info"]},  # Only use position info
        observation_space=Dict({
            "info": Box(low=0, high=255, shape=(4,), dtype=np.float32)  # Adjusted shape and dtype
        })
    )
    return train_env

# Number of parallel environments
num_envs = 4  # Use 4 parallel environments
vec_env = SubprocVecEnv([make_env for _ in range(num_envs)])

# Continue training the model
model.set_env(vec_env)  # Ensure the model is using the correct environment

# Continue training from the previous state for a set number of timesteps
model.learn(total_timesteps=50000)  # Continue training for 50,000 timesteps (or any other number)
model.save("ppo_medarot")  # Save the model again after additional training
# Out:
# Logging to ./ppo_tensorboard/PPO_21
# ------------------------------
# | time/              |       |
# |    fps             | 75    |
# |    iterations      | 1     |
# |    time_elapsed    | 217   |
# |    total_timesteps | 16384 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 2           |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015452752 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.159      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00999    |
# |    value_loss           | 0.0319      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 3           |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011509961 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.152      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 0.0171      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 4            |
# |    time_elapsed         | 835          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0066913106 |
# |    clip_fraction        | 0.0689       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0.0229       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.164       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 0.00375      |
# ------------------------------------------

# %% [markdown]
# # Plot Logs

# %%
# Load training logs
log_df = pd.read_csv("./ppo_medarot_logs.monitor.csv", skiprows=1)

# Plot episode rewards
plt.figure(figsize=(10, 5))
plt.plot(log_df["r"], label="Episode Reward", alpha=0.7)
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.title("Training Reward Over Episodes")
plt.legend()
plt.show()

# Plot episode lengths
plt.figure(figsize=(10, 5))
plt.plot(log_df["l"], label="Episode Length", color="red", alpha=0.7)
plt.xlabel("Episode")
plt.ylabel("Length (Steps)")
plt.title("Training Episode Length Over Time")
plt.legend()
plt.show()
